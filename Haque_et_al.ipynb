# %% [markdown]
# # **A Deep Learning Approach to Detect COVID-19 Patients from Chest X-ray Images**
#
# References
#
#
# 1.   [A Deep Learning Approach to Detect COVID-19 Patients from Chest X-ray Images](https://www.researchgate.net/publication/344340531_A_Deep_Learning_Approach_to_Detect_COVID-19_Patients_from_Chest_X-ray_Images)
# 2.   [ImageNet training in PyTorch](https://github.com/pytorch/examples/blob/537f6971872b839b36983ff40dafe688276fe6c3/imagenet/main.py)
# 3. [CS231n Convolutional Neural Networks for Visual Recognition](https://cs231n.github.io/convolutional-networks/)
# 4. [Kaggle COVID-19 Radiography Dataset](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
# 5. [NIH Chest X-ray Dataset](https://nihcc.app.box.com/v/ChestXray-NIHCC/folder/36938765345)
# 6. [XRay CNN in PyTorch](https://www.kaggle.com/salvation23/xray-cnn-pytorch)
# 7. [Plot ROC curve](https://stackoverflow.com/questions/25009284/how-to-plot-roc-curve-in-python)
# 8. [Plot Confusion Matrix](https://medium.com/@dtuk81/confusion-matrix-visualization-fc31e3f30fea)

# %% [markdown]
# **Install missing packages**
#
# Some required packages are not installed by default in Google Colab. It is necessary to manually install them for each user session.

# %%
# !pip install utils
# !pip install split-folders tqdm
# Out:
# Collecting utils
#   Downloading https://files.pythonhosted.org/packages/55/e6/c2d2b2703e7debc8b501caae0e6f7ead148fd0faa3c8131292a599930029/utils-1.0.1-py2.py3-none-any.whl
# Installing collected packages: utils
# Successfully installed utils-1.0.1
# Collecting split-folders
#   Downloading https://files.pythonhosted.org/packages/b8/5f/3c2b2f7ea5e047c8cdc3bb00ae582c5438fcdbbedcc23b3cc1c2c7aae642/split_folders-0.4.3-py3-none-any.whl
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.41.1)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.4.3

# %% [markdown]
# **Setup the environment and variables**
#
# The following steps are done
#
# 1.   Import all the necessary modules
# 2.   Set the random number seed. This is required for reproducing the results every time.
# 3. Set the global variables
#
# If the flag *save_cloud* is *True*, the outputs will be stored in Google Drive. When this option is selected, the notebook will prompt to enter an API key from Google.

# %%
import os
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import utils as utils
import time
import math
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch.optim as optim
import gdown
import splitfolders
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime
import glob
import copy
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, roc_curve, auc
import pickle
from google.colab import drive

# Set the random number seed. This allows results to be reproduced
seed = 1619
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)

# If True, the output will be stored in Google Drive and will be permanent. Otherwise it will be stored in the Colab workspace which is highly volatile
save_cloud = True

# Hyperparameters
BATCH_SIZE = 32
LEARNING_RATE = 0.0001
NUM_EPOCHS = 100

# Global variables
DATASET_URL = 'https://drive.google.com/uc?id=1ZrnMdjrJAyJwdsH1L2W6pmL8hjFFuhqw'
DATA_PATH = "/content/data_split/"
UNZIP_LOC = '/content/data/'
ZIPFILE = 'dataset.zip'

if save_cloud:
  # Mount Google Drive. This will require manually authenticating with an API key per user session
  drive.mount('/content/gdrive', force_remount=True)
  MODEL_ROOT = '/content/gdrive/My Drive/models/'
else:
  MODEL_ROOT = '/content/models/'

MODEL_NAME= 'CovidCNN'
MODEL_PATH = f"{MODEL_ROOT}/{MODEL_NAME}/{datetime.today().strftime('%m-%d-%Y')}/{datetime.today().strftime('%H:%M')}/"

# Flag to check if GPU is available for use.
use_gpu = torch.cuda.is_available()

# Location for storing best model and checkpoints
if not os.path.exists(MODEL_PATH):
   os.makedirs(MODEL_PATH, exist_ok=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **Environment details**
#
# Google Colab provides GPUs that help with resource intensive Deep Learning operations. It also comes pre-loaded with PyTorch that is required in this notebook.

# %%
# GPU Information
# !nvidia-smi

# PyTorch library version
print(f"\n\nPyTorch version: {torch.__version__}")
# Out:
# Fri May  7 06:12:04 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    33W / 250W |   4243MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
#
#
# PyTorch version: 1.8.1+cu101

# %% [markdown]
# **Download dataset**
#
# The dataset is stored in Google Drive as a zip file. The following code downloads the zip file to the Colab workspace and then unzips it.
#
# The dataset contains 7200 Chest X Rays in total. This is a balanced dataset with 3600 COVID XRays and 3600 non-COVID XRays.

# %%
# Remove existing dataset files to avoid conflicts
# !rm -rf "{UNZIP_LOC}"
# !rm -rf "{DATA_PATH}"
# !rm "{ZIPFILE}"

# Download from Google drive to Colab
gdown.download(DATASET_URL, ZIPFILE, quiet=False)

# Unzip the file in the Colab workspace
# !unzip -q "{ZIPFILE}" -d "{UNZIP_LOC}"
# Out:
# rm: cannot remove 'dataset.zip': No such file or directory
# Downloading...
# From: https://drive.google.com/uc?id=1ZrnMdjrJAyJwdsH1L2W6pmL8hjFFuhqw
# To: /content/dataset.zip
# 1.55GB [00:15, 102MB/s]

# %% [markdown]
# Validate the dataset image count

# %%
assert len(os.listdir(UNZIP_LOC + 'COVID')) == 3600, "COVID Xray count wrong. Imbalanced dataset"
assert len(os.listdir(UNZIP_LOC + 'Non-COVID')) == 3600, "Non-COVID Xray count wrong. Imbalanced dataset"

# %% [markdown]
# **Dataset split**
#
# The dataset needs to be split for training, test and validation. This train/test/validation ratio is 60% : 20% : 20%.

# %%
splitfolders.ratio(UNZIP_LOC, output= DATA_PATH, seed=seed, ratio=(0.6,0.2,0.2))
# Out:
# Copying files: 7200 files [00:19, 365.05 files/s]

# %% [markdown]
# Validate that the count of files after the dataset split is unchanged.

# %%
total_files = sum([len(files) for _, _, files in os.walk(UNZIP_LOC)])
total_split_files = sum([len(files) for _, _, files in os.walk(DATA_PATH)])

assert total_files == total_split_files, "XRay count after the dataset split is wrong."

# %% [markdown]
# **Image Pre-processing**
#
# The following image transformations are done on the images.
#
#
# 1.   Resize to 224 x 224 pixels
# 2.   Normalize to ensure that every pixel has a similar data distribution.

# %%
def get_XRay_count(folder, data_path=DATA_PATH):

    covid_path = data_path + folder + '/COVID' 
    non_covid_path = data_path + folder + '/Non-COVID'

    covid_count = (len(os.listdir(covid_path)))
    non_covid_count = (len(os.listdir(non_covid_path)))

    return covid_count, non_covid_count

def load_data(data_path=DATA_PATH):

    transformed_img = transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
    ])

    train_path = DATA_PATH + '/train' 
    train_data = datasets.ImageFolder(root=train_path, 
                                      transform=transformed_img)
    train_loader = torch.utils.data.DataLoader(train_data,batch_size=BATCH_SIZE,shuffle= True)

    val_path = DATA_PATH + '/val' 
    val_data = datasets.ImageFolder(root=val_path, 
                                    transform=transformed_img)
    val_loader = torch.utils.data.DataLoader(val_data,batch_size=BATCH_SIZE,shuffle= False)
    
    test_path = DATA_PATH + '/test' 
    test_data = datasets.ImageFolder(root=test_path, 
                                    transform=transformed_img)
    test_loader = torch.utils.data.DataLoader(test_data, 
                                             batch_size=BATCH_SIZE,shuffle = False)    
    
    return train_loader, val_loader, test_loader

# %% [markdown]
# **Loading DataLoaders**
#
# Transform the images and load the DataLoader objects for  train/test/val. This will be used for training and testing the model later.

# %%
# Call the function to load the train, test and validation dataloaders from the dataset.
train_loader, val_loader, test_loader = load_data()

# %% [markdown]
# Validate that the count of XRays in the train/val/test folders is as per the dataset split ratio.

# %%
# Validate the number of entries in train, test and val folders
assert get_XRay_count('train') == (2160, 2160), "train folder XRay count is wrong"
assert get_XRay_count('val') == (720, 720), "val folder XRay count is wrong"
assert get_XRay_count('test') == (720, 720), "test folder XRay count is wrong"

# Validate the length of the dataloaders
assert len(train_loader) == math.ceil(4320/BATCH_SIZE), "Train dataloader length is wrong"
assert len(val_loader) == math.ceil(1440/BATCH_SIZE), "Val dataloader length is wrong"
assert len(test_loader) == math.ceil(1440/BATCH_SIZE), "Test dataloader length is wrong"

# %% [markdown]
# Show some sample images from the dataloader.

# %%
def imshow(img, title):
    npimg = img.numpy()
    plt.figure(figsize=(15, 7))
    plt.axis('off')
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title(title)
    plt.show()

def show_batch_images(dataloader):
    images, labels = next(iter(dataloader))
    img = torchvision.utils.make_grid(images, padding=25)
    imshow(img, title=["COVID" if x==0  else "Non-COVID" for x in labels])

show_batch_images(train_loader)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # **Model Definition**
#
# In the paper titled [A Deep Learning Approach to Detect COVID-19 Patients from Chest X-ray Images](https://www.researchgate.net/publication/344340531_A_Deep_Learning_Approach_to_Detect_COVID-19_Patients_from_Chest_X-ray_Images), Haque et al. proposed a model that uses Convolutional Neural Networks (CNNs) to predict COVID-19 patients using Chest X-Rays(CXRs).
#
# The model has four 2D convolutional layers that have a kernel size of 3 x 3 and employs the Rectified Linear Unit (ReLU) activation function. Convolution layers 2, 3 and 4 have a Max. pooling layer of kernel size 2 x 2 to avoid overfitting. At the last convolutional layer, the output is flattened to a 1D vector and fed to a Fully Connected(FC) layer.  A Sigmoid activation function in the FC layer makes the classification. The architecture diagram is given below.
#
# ![CNN](https://www.researchgate.net/profile/Khandaker-Haque-2/publication/344340531/figure/fig4/AS:938577072513024@1600785620239/Workflow-diagram-of-the-proposed-CNN-model-for-COVID-19-detection.jpg)

# %%
class CovidCNN(nn.Module):
    def __init__(self):
        super(CovidCNN, self).__init__()

        self.conv1 = nn.Sequential( 
            nn.Conv2d(in_channels = 3, out_channels = 32, kernel_size = (3,3), stride=(1,1), padding=0),
            nn.ReLU(inplace=True)
        )
                 
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels = 32, out_channels = 64, kernel_size = (3,3), stride=(1,1), padding=0),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )

        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels = 64, out_channels = 64, kernel_size = (3,3), stride=(1,1), padding=0),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )

        self.conv4 = nn.Sequential(
            nn.Conv2d(in_channels = 64, out_channels = 128, kernel_size = (3,3), stride=(1,1), padding=0),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(),
            nn.Flatten()
        )
        
        self.fc = nn.Sequential(
            nn.Linear(in_features = 128 * 26 * 26, out_features = 2),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)

        x = self.fc(x)
        
        return x

# %% [markdown]
# **Loss function and Optimizer**
#
# The Cross Entropy loss function is used along with the Adam optimzer.

# %%
model = CovidCNN()

criterion = None
optimizer = None

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

if use_gpu:
    model.cuda()
    criterion = criterion.cuda()

# %% [markdown]
# **Helper functions**
#
#
#
# 1.   ***save_file*** - Save a Python object as a binary stream
# 2.   ***read_file*** - Read from a binary stream to a Python object
# 3.   ***save_checkpoint*** - Save the current epoch checkpoint for resuming training later
# 4.   ***get_savedmodel*** - This function is used to retrieve a previously saved model. It has 3 modes
#
# *   BESTMODEL   -> Returns the best model after training(with the highest validation accuracy)
# *   FINALMODEL  -> Returns the model from the last epoch after training
# *   RESUMETRAIN -> Resumes training on an incomplete model and returns the model
#
# 5.   ***plot_training_metrics*** - Plot and save graphs with training metrics

# %%
def save_file(file_tosave, fname, fpath = MODEL_PATH):
  with open(f"{fpath}/{fname}.data", 'wb') as fh:
      pickle.dump(file_tosave, fh)

def read_file(fname, fpath = MODEL_PATH):
  with open(f"{fpath}/{fname}.data", 'rb') as fh:
      out = pickle.load(fh)
  return out

def save_checkpoint(model_state, checkpoint_path):
  torch.save(model_state, checkpoint_path)

def get_savedmodel(checkpoint_loc, mode = 'BESTMODEL'):

  # Create a new instance of the model and optimizer
  model = CovidCNN()
  optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

  if use_gpu:
      model.cuda()

  # Load the model checkpoint
  checkpoint = torch.load(f"{checkpoint_loc}/last_model_state.pth")
  epoch_metrics = checkpoint['epoch_metrics']

  if mode == 'BESTMODEL':
    model.load_state_dict(torch.load(f"{checkpoint_loc}/best_model.pth"))
  else:
    # Load model and optimizer weights from the checkpoint
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])

    epoch = checkpoint['epoch']
    
    if mode == 'RESUMETRAIN':
      # Train the model from the checkpoint and return the model
       model, epoch_metrics = train_model(model, train_loader, val_loader, start_epoch = epoch+1, epoch_metrics = epoch_metrics )

    # For mode = 'FINALMODEL', do nothing and just return whatever is already inside model and epoch_metrics

  # Return the required model
  return model, epoch_metrics

def plot_training_metrics(epoch_metrics):

  epoch_list=  list(range(1, NUM_EPOCHS+1))

  sns.set_style("darkgrid")
  plt.plot(epoch_list, epoch_metrics["val_losses"], label='Validation Loss')
  plt.plot(epoch_list, epoch_metrics["val_accuracy"], label='Validation Accuracy')
  plt.title('Accuracy/Training Loss over epochs')
  plt.ylabel('Accuracy/Loss')
  plt.xlabel('Epoch')
  plt.ylim([0, 1])
  plt.legend(['Validation Loss', 'Validation Accuracy'], loc='lower right')
  plt.savefig(f"{MODEL_PATH}Accuracy_Epoch.png")
  plt.show()

  plt.figure(figsize = (12, 6))
  plt.grid(True)
  plt.plot(epoch_list, epoch_metrics["epoch_timer"], label='Epoch Time')
  plt.title('Epoch Training Time')
  plt.ylabel('Training Time')
  plt.xlabel('Epoch')
  plt.legend(['Training Time'], loc='lower right')
  plt.savefig(f"{MODEL_PATH}Training_Epoch.png")
  plt.show()

# %% [markdown]
# **Training**
#
# The model training consists of the following steps in each epoch:
#
# 1.   In the training mode, run the training steps for each batch within the training dataloader.
# 2.   In evaluation mode, validate the the model trained till then for each batch within the validation dataloader.
# 3.   Calculate validation accuracy. If validation accuracy is more than the best validation accuracy till then,
#
#   *   Save the current model as the best model yet.
#   *   Update best validation accuracy to current validation accuracy.
#
# 4.   Save model state as a checkpoint to resume training later in case of failure.
#
# At the end of training, the best model based on validaton accuracy is retrieved and returned.

# %%
def train_model(model, train_dataloader, val_dataloader, start_epoch = 0, epoch_metrics = {}, n_epoch=NUM_EPOCHS, optimizer=optimizer, criterion=criterion):

    # Set the model in training mode
    model.train()
    
    bestmodel_path = f"{MODEL_PATH}best_model.pth"

    # If this is a fresh run, initialize the metrics dict. If resuming training, epoch_metrics will already have data from the last checkpoint
    if len(epoch_metrics) == 0:
      epoch_metrics = dict({
          'train_losses' : [], 
          'train_accuracy': [], 
          'val_losses' : [], 
          'val_accuracy': [], 
          'epoch_timer': [], 
          'best_val_accuracy': 0.0,
          'best_epoch': 0
          })
   
    for epoch in range(start_epoch, n_epoch):
    
      epoch_starttime = time.time()
      running_train_loss = 0
      running_val_loss = 0
      running_train_correct = 0
      running_val_correct = 0

      # Training loop
      for images, labels in train_dataloader:

        if use_gpu:
            images, labels = images.cuda(), labels.cuda()

        # Clear parameter gradients
        optimizer.zero_grad()

        # forward pass
        outputs = model(images)
     
        #Calculate loss
        loss = criterion(outputs, labels )

        # Loss for batch
        running_train_loss += loss.item() * images.size(0)

        _, preds = torch.max(outputs, 1)

        # backward pass
        loss.backward()
        
        #Perform single optimization step
        optimizer.step()

        # Correct predictions
        running_train_correct += (preds == labels).sum().item()        

      # Validation loop
      for images, labels in val_dataloader:
        if use_gpu:
            images, labels = images.cuda(), labels.cuda()
        
        # Eval mode
        model.eval()
        
        output = model(images)
        loss = criterion(output, labels)
        _, preds = torch.max(output, 1)

        # Calculate validation loss and correct predictions
        running_val_loss += loss.item() * images.size(0)
        running_val_correct += (preds == labels).sum().item()
      
      # Put back in train mode for next epoch
      model.train()
  
      # Calculate loss and accuracy for training and validation
      epoch_train_loss = running_train_loss / len(train_dataloader.dataset)
      epoch_train_accuracy = running_train_correct / len(train_dataloader.dataset)
      epoch_val_loss = running_val_loss / len(val_dataloader.dataset)
      epoch_val_accuracy = running_val_correct / len(val_dataloader.dataset)

      print(
          f"Epoch {epoch+1}, Train loss : {epoch_train_loss:.4f}, Training accuracy: {epoch_train_accuracy:.4f}, "
          f"Validation loss :{epoch_val_loss:.4f}, Validation accuracy: {epoch_val_accuracy:.4f}"
          )
      
      # Arrays having values from all epochs for plotting graphs
      epoch_metrics["train_losses"].append(epoch_train_loss)
      epoch_metrics["train_accuracy"].append(epoch_train_accuracy)
      epoch_metrics["val_losses"].append(epoch_val_loss)
      epoch_metrics["val_accuracy"].append(epoch_val_accuracy)
      epoch_metrics["epoch_timer"].append(time.time() - epoch_starttime) 
      
      # If validation accuracy improves, save it so that the best model can be picked up at the end
      if epoch_val_accuracy > epoch_metrics["best_val_accuracy"]:
          print(f"Validation accuracy increased from {epoch_metrics['best_val_accuracy']:.4f} -> {epoch_val_accuracy:.4f}. Saving model...")
          epoch_metrics["best_val_accuracy"] = epoch_val_accuracy
          epoch_metrics["best_epoch"] = epoch + 1
          torch.save(copy.deepcopy(model.state_dict()), bestmodel_path)

      # Save the checkpoint after every epoch so that if needed, training can be resumed from this point later on
      checkpoint_path = f"{MODEL_PATH}last_model_state.pth"
      save_checkpoint({
          'epoch': epoch,
          'state_dict': copy.deepcopy(model.state_dict()),
          'optimizer' : copy.deepcopy(optimizer.state_dict()),
          'loss': criterion,
          'epoch_metrics': epoch_metrics
      }, checkpoint_path)
      
    # At the end of training, Retrieve best model
    print(f"TRAINING COMPLETE!! Model saved at {bestmodel_path}")
    model = CovidCNN()
    if use_gpu:
      model.cuda()

    model.load_state_dict(torch.load(bestmodel_path))
    
    return model, epoch_metrics

# %% [markdown]
# **Training the model**

# %%
# Train the model
model, epoch_metrics = train_model(model, train_loader, val_loader)
# Out:
# Epoch 1, Train loss : 0.6861, Training accuracy: 0.5507, Validation loss :0.6827, Validation accuracy: 0.5924
# Validation accuracy increased from 0.0000 -> 0.5924. Saving model...
# Epoch 2, Train loss : 0.6787, Training accuracy: 0.5738, Validation loss :0.6791, Validation accuracy: 0.5472
# Epoch 3, Train loss : 0.6699, Training accuracy: 0.5896, Validation loss :0.6640, Validation accuracy: 0.5979
# Validation accuracy increased from 0.5924 -> 0.5979. Saving model...
# Epoch 4, Train loss : 0.6613, Training accuracy: 0.6042, Validation loss :0.6570, Validation accuracy: 0.6049
# Validation accuracy increased from 0.5979 -> 0.6049. Saving model...
# Epoch 5, Train loss : 0.6347, Training accuracy: 0.6431, Validation loss :0.6517, Validation accuracy: 0.6264
# Validation accuracy increased from 0.6049 -> 0.6264. Saving model...
# Epoch 6, Train loss : 0.6249, Training accuracy: 0.6509, Validation loss :0.6222, Validation accuracy: 0.6639
# Validation accuracy increased from 0.6264 -> 0.6639. Saving model...
# Epoch 7, Train loss : 0.6118, Training accuracy: 0.6775, Validation loss :0.6021, Validation accuracy: 0.6889
# Validation accuracy increased from 0.6639 -> 0.6889. Saving model...
# Epoch 8, Train loss : 0.6104, Training accuracy: 0.6752, Validation loss :0.6000, Validation accuracy: 0.6958
# Validation accuracy increased from 0.6889 -> 0.6958. Saving model...
# Epoch 9, Train loss : 0.5947, Training accuracy: 0.6926, Validation loss :0.6044, Validation accuracy: 0.6792
# Epoch 10, Train loss : 0.5973, Training accuracy: 0.6861, Validation loss :0.5852, Validation accuracy: 0.7049
# Validation accuracy increased from 0.6958 -> 0.7049. Saving model...
# Epoch 11, Train loss : 0.5817, Training accuracy: 0.7042, Validation loss :0.5698, Validation accuracy: 0.7333
# Validation accuracy increased from 0.7049 -> 0.7333. Saving model...
# Epoch 12, Train loss : 0.5779, Training accuracy: 0.7125, Validation loss :0.5940, Validation accuracy: 0.6910
# Epoch 13, Train loss : 0.5671, Training accuracy: 0.7218, Validation loss :0.5849, Validation accuracy: 0.6965
# Epoch 14, Train loss : 0.5534, Training accuracy: 0.7458, Validation loss :0.6237, Validation accuracy: 0.6500
# Epoch 15, Train loss : 0.5681, Training accuracy: 0.7273, Validation loss :0.5450, Validation accuracy: 0.7583
# Validation accuracy increased from 0.7333 -> 0.7583. Saving model...
# Epoch 16, Train loss : 0.5474, Training accuracy: 0.7509, Validation loss :0.5292, Validation accuracy: 0.7708
# Validation accuracy increased from 0.7583 -> 0.7708. Saving model...
# Epoch 17, Train loss : 0.5399, Training accuracy: 0.7618, Validation loss :0.5302, Validation accuracy: 0.7701
# Epoch 18, Train loss : 0.5242, Training accuracy: 0.7815, Validation loss :0.5081, Validation accuracy: 0.8007
# Validation accuracy increased from 0.7708 -> 0.8007. Saving model...
# Epoch 19, Train loss : 0.5021, Training accuracy: 0.8076, Validation loss :0.6183, Validation accuracy: 0.6590
# Epoch 20, Train loss : 0.5104, Training accuracy: 0.7958, Validation loss :0.5106, Validation accuracy: 0.7958
# Epoch 21, Train loss : 0.4853, Training accuracy: 0.8287, Validation loss :0.4615, Validation accuracy: 0.8562
# Validation accuracy increased from 0.8007 -> 0.8562. Saving model...
# Epoch 22, Train loss : 0.4951, Training accuracy: 0.8083, Validation loss :0.4634, Validation accuracy: 0.8451
# Epoch 23, Train loss : 0.4750, Training accuracy: 0.8384, Validation loss :0.5199, Validation accuracy: 0.7799
# Epoch 24, Train loss : 0.4686, Training accuracy: 0.8400, Validation loss :0.5397, Validation accuracy: 0.7556
# Epoch 25, Train loss : 0.4710, Training accuracy: 0.8407, Validation loss :0.4574, Validation accuracy: 0.8528
# Epoch 26, Train loss : 0.4511, Training accuracy: 0.8604, Validation loss :0.4499, Validation accuracy: 0.8583
# Validation accuracy increased from 0.8562 -> 0.8583. Saving model...
# Epoch 27, Train loss : 0.4458, Training accuracy: 0.8671, Validation loss :0.4289, Validation accuracy: 0.8833
# Validation accuracy increased from 0.8583 -> 0.8833. Saving model...
# Epoch 28, Train loss : 0.4440, Training accuracy: 0.8632, Validation loss :0.4451, Validation accuracy: 0.8681
# Epoch 29, Train loss : 0.4354, Training accuracy: 0.8785, Validation loss :0.4287, Validation accuracy: 0.8847
# Validation accuracy increased from 0.8833 -> 0.8847. Saving model...
# Epoch 30, Train loss : 0.4318, Training accuracy: 0.8810, Validation loss :0.4357, Validation accuracy: 0.8743
# Epoch 31, Train loss : 0.4216, Training accuracy: 0.8914, Validation loss :0.4319, Validation accuracy: 0.8757
# Epoch 32, Train loss : 0.4176, Training accuracy: 0.8921, Validation loss :0.4081, Validation accuracy: 0.9049
# Validation accuracy increased from 0.8847 -> 0.9049. Saving model...
# Epoch 33, Train loss : 0.4360, Training accuracy: 0.8750, Validation loss :0.4399, Validation accuracy: 0.8708
# Epoch 34, Train loss : 0.4364, Training accuracy: 0.8757, Validation loss :0.3957, Validation accuracy: 0.9229
# Validation accuracy increased from 0.9049 -> 0.9229. Saving model...
# Epoch 35, Train loss : 0.4253, Training accuracy: 0.8856, Validation loss :0.4254, Validation accuracy: 0.8847
# Epoch 36, Train loss : 0.3997, Training accuracy: 0.9183, Validation loss :0.4113, Validation accuracy: 0.9007
# Epoch 37, Train loss : 0.4212, Training accuracy: 0.8905, Validation loss :0.4073, Validation accuracy: 0.9104
# Epoch 38, Train loss : 0.4082, Training accuracy: 0.9037, Validation loss :0.4132, Validation accuracy: 0.9021
# Epoch 39, Train loss : 0.4207, Training accuracy: 0.8882, Validation loss :0.4091, Validation accuracy: 0.8986
# Epoch 40, Train loss : 0.4014, Training accuracy: 0.9120, Validation loss :0.4010, Validation accuracy: 0.9118
# Epoch 41, Train loss : 0.3991, Training accuracy: 0.9125, Validation loss :0.4201, Validation accuracy: 0.8861
# Epoch 42, Train loss : 0.4081, Training accuracy: 0.9030, Validation loss :0.4346, Validation accuracy: 0.8653
# Epoch 43, Train loss : 0.4144, Training accuracy: 0.9005, Validation loss :0.4546, Validation accuracy: 0.8528
# Epoch 44, Train loss : 0.4125, Training accuracy: 0.8984, Validation loss :0.4284, Validation accuracy: 0.8847
# Epoch 45, Train loss : 0.4001, Training accuracy: 0.9116, Validation loss :0.3946, Validation accuracy: 0.9139
# Epoch 46, Train loss : 0.3820, Training accuracy: 0.9306, Validation loss :0.3838, Validation accuracy: 0.9306
# Validation accuracy increased from 0.9229 -> 0.9306. Saving model...
# Epoch 47, Train loss : 0.4143, Training accuracy: 0.8965, Validation loss :0.3936, Validation accuracy: 0.9181
# Epoch 48, Train loss : 0.3960, Training accuracy: 0.9164, Validation loss :0.3868, Validation accuracy: 0.9271
# Epoch 49, Train loss : 0.4051, Training accuracy: 0.9060, Validation loss :0.3938, Validation accuracy: 0.9201
# Epoch 50, Train loss : 0.3924, Training accuracy: 0.9201, Validation loss :0.4196, Validation accuracy: 0.8889
# Epoch 51, Train loss : 0.3885, Training accuracy: 0.9245, Validation loss :0.3986, Validation accuracy: 0.9125
# Epoch 52, Train loss : 0.4026, Training accuracy: 0.9060, Validation loss :0.4037, Validation accuracy: 0.9049
# Epoch 53, Train loss : 0.3906, Training accuracy: 0.9201, Validation loss :0.3790, Validation accuracy: 0.9326
# Validation accuracy increased from 0.9306 -> 0.9326. Saving model...
# Epoch 54, Train loss : 0.3957, Training accuracy: 0.9176, Validation loss :0.3920, Validation accuracy: 0.9208
# Epoch 55, Train loss : 0.3859, Training accuracy: 0.9259, Validation loss :0.3955, Validation accuracy: 0.9118
# Epoch 56, Train loss : 0.3836, Training accuracy: 0.9292, Validation loss :0.3683, Validation accuracy: 0.9479
# Validation accuracy increased from 0.9326 -> 0.9479. Saving model...
# Epoch 57, Train loss : 0.3791, Training accuracy: 0.9317, Validation loss :0.4175, Validation accuracy: 0.8868
# Epoch 58, Train loss : 0.4015, Training accuracy: 0.9090, Validation loss :0.3862, Validation accuracy: 0.9236
# Epoch 59, Train loss : 0.3840, Training accuracy: 0.9294, Validation loss :0.3626, Validation accuracy: 0.9583
# Validation accuracy increased from 0.9479 -> 0.9583. Saving model...
# Epoch 60, Train loss : 0.3732, Training accuracy: 0.9384, Validation loss :0.3738, Validation accuracy: 0.9389
# Epoch 61, Train loss : 0.3827, Training accuracy: 0.9303, Validation loss :0.4325, Validation accuracy: 0.8736
# Epoch 62, Train loss : 0.3891, Training accuracy: 0.9199, Validation loss :0.4739, Validation accuracy: 0.8257
# Epoch 63, Train loss : 0.3878, Training accuracy: 0.9236, Validation loss :0.3965, Validation accuracy: 0.9201
# Epoch 64, Train loss : 0.3774, Training accuracy: 0.9345, Validation loss :0.3645, Validation accuracy: 0.9479
# Epoch 65, Train loss : 0.3795, Training accuracy: 0.9324, Validation loss :0.3851, Validation accuracy: 0.9250
# Epoch 66, Train loss : 0.3754, Training accuracy: 0.9366, Validation loss :0.3711, Validation accuracy: 0.9417
# Epoch 67, Train loss : 0.3789, Training accuracy: 0.9333, Validation loss :0.3576, Validation accuracy: 0.9563
# Epoch 68, Train loss : 0.3679, Training accuracy: 0.9461, Validation loss :0.4042, Validation accuracy: 0.9090
# Epoch 69, Train loss : 0.3727, Training accuracy: 0.9400, Validation loss :0.5008, Validation accuracy: 0.8028
# Epoch 70, Train loss : 0.3689, Training accuracy: 0.9437, Validation loss :0.3541, Validation accuracy: 0.9597
# Validation accuracy increased from 0.9583 -> 0.9597. Saving model...
# Epoch 71, Train loss : 0.3705, Training accuracy: 0.9437, Validation loss :0.3924, Validation accuracy: 0.9125
# Epoch 72, Train loss : 0.3813, Training accuracy: 0.9306, Validation loss :0.3621, Validation accuracy: 0.9535
# Epoch 73, Train loss : 0.3713, Training accuracy: 0.9419, Validation loss :0.3610, Validation accuracy: 0.9500
# Epoch 74, Train loss : 0.3694, Training accuracy: 0.9426, Validation loss :0.3642, Validation accuracy: 0.9486
# Epoch 75, Train loss : 0.3716, Training accuracy: 0.9421, Validation loss :0.3732, Validation accuracy: 0.9347
# Epoch 76, Train loss : 0.3697, Training accuracy: 0.9428, Validation loss :0.3664, Validation accuracy: 0.9500
# Epoch 77, Train loss : 0.3717, Training accuracy: 0.9403, Validation loss :0.4127, Validation accuracy: 0.8910
# Epoch 78, Train loss : 0.3686, Training accuracy: 0.9440, Validation loss :0.3608, Validation accuracy: 0.9514
# Epoch 79, Train loss : 0.3747, Training accuracy: 0.9354, Validation loss :0.4545, Validation accuracy: 0.8556
# Epoch 80, Train loss : 0.3727, Training accuracy: 0.9398, Validation loss :0.3674, Validation accuracy: 0.9479
# Epoch 81, Train loss : 0.3638, Training accuracy: 0.9495, Validation loss :0.3633, Validation accuracy: 0.9535
# Epoch 82, Train loss : 0.3599, Training accuracy: 0.9549, Validation loss :0.3866, Validation accuracy: 0.9264
# Epoch 83, Train loss : 0.3641, Training accuracy: 0.9481, Validation loss :0.3733, Validation accuracy: 0.9382
# Epoch 84, Train loss : 0.3788, Training accuracy: 0.9310, Validation loss :0.3575, Validation accuracy: 0.9590
# Epoch 85, Train loss : 0.3591, Training accuracy: 0.9528, Validation loss :0.3414, Validation accuracy: 0.9785
# Validation accuracy increased from 0.9597 -> 0.9785. Saving model...
# Epoch 86, Train loss : 0.3581, Training accuracy: 0.9565, Validation loss :0.3630, Validation accuracy: 0.9507
# Epoch 87, Train loss : 0.3593, Training accuracy: 0.9532, Validation loss :0.3519, Validation accuracy: 0.9625
# Epoch 88, Train loss : 0.3760, Training accuracy: 0.9347, Validation loss :0.3933, Validation accuracy: 0.9215
# Epoch 89, Train loss : 0.3552, Training accuracy: 0.9583, Validation loss :0.3911, Validation accuracy: 0.9160
# Epoch 90, Train loss : 0.3636, Training accuracy: 0.9493, Validation loss :0.3520, Validation accuracy: 0.9653
# Epoch 91, Train loss : 0.3608, Training accuracy: 0.9530, Validation loss :0.4033, Validation accuracy: 0.9028
# Epoch 92, Train loss : 0.3800, Training accuracy: 0.9301, Validation loss :0.3661, Validation accuracy: 0.9451
# Epoch 93, Train loss : 0.3526, Training accuracy: 0.9620, Validation loss :0.3431, Validation accuracy: 0.9701
# Epoch 94, Train loss : 0.3520, Training accuracy: 0.9613, Validation loss :0.3611, Validation accuracy: 0.9479
# Epoch 95, Train loss : 0.3580, Training accuracy: 0.9563, Validation loss :0.3665, Validation accuracy: 0.9486
# Epoch 96, Train loss : 0.3629, Training accuracy: 0.9495, Validation loss :0.3616, Validation accuracy: 0.9528
# Epoch 97, Train loss : 0.3512, Training accuracy: 0.9616, Validation loss :0.3708, Validation accuracy: 0.9437
# Epoch 98, Train loss : 0.3619, Training accuracy: 0.9514, Validation loss :0.3575, Validation accuracy: 0.9535
# Epoch 99, Train loss : 0.3611, Training accuracy: 0.9509, Validation loss :0.3612, Validation accuracy: 0.9500
# Epoch 100, Train loss : 0.3548, Training accuracy: 0.9593, Validation loss :0.3560, Validation accuracy: 0.9542
# TRAINING COMPLETE!!

# %% [markdown]
# **Load previously trained model (only if required)**
#
# Run this cell to load a previously trained model. If the saved model was not trained completely, set the *resume_training* flag to True to load the model from the checkpoint and resume training. This need not be run under usual circumstances.

# %%
# Update the model path to the output folder where the model is saved
MODEL_PATH = '/content/gdrive/MyDrive/models/CovidCNN/05-07-2021/03:33/'

# BESTMODEL   -> To return the best performing model
# FINALMODEL   -> To return the best model after the last epoch
# RESUMETRAIN -> To resume an incomplete training
mode = 'BESTMODEL'

model, epoch_metrics = get_savedmodel(MODEL_PATH, mode)
print("MODEL LOADED!")

# %% [markdown]
# **Plot training metric graphs**

# %%
# epoch_metrics contains lists having accuracy and loss for each epoch during training and validation   
plot_training_metrics(epoch_metrics)

# %% [markdown]
# **Testing the model**
#
# On the trained model, run the testing dataset and return the predictions along with the ground truths.

# %%
def eval_model(model, dataloader):

  model.eval()

  Y_pred = []
  Y_test = []

  with torch.no_grad():
      for images, labels in dataloader:
          if use_gpu:
            images, labels = images.cuda(), labels.cuda()
          y_pred = model(images)
          _, y_pred_tag = torch.max(y_pred, 1)

          Y_pred = np.append(Y_pred,y_pred_tag.cpu().detach().numpy())
          Y_test = np.append(Y_test,labels.cpu().numpy())

  print("MODEL TESTING COMPLETE!")
  return Y_pred, Y_test



# Test the model
y_pred, y_true = eval_model(model, test_loader)
# Out:
# MODEL TESTING COMPLETE!

# %% [markdown]
# **Calculating performance metrics**

# %%
  # Print metrics
  accuracy = accuracy_score(y_true, y_pred)
  precision, recall, fscore, support = precision_recall_fscore_support(y_true, y_pred
                                                                       , average='macro'
                                                                      )
 
  # ROC curve
  false_posrate, true_posrate, threshold = roc_curve(y_true, y_pred)
  
  # AUC
  roc_auc = auc(false_posrate, true_posrate)

  # Confusion matrix
  np.set_printoptions(threshold=np.inf) 
  conf_matrix = confusion_matrix(y_true, y_pred)

  # Calculate the training time
  train_time = sum(epoch_metrics['epoch_timer'])

  print(f"TESTING METRICS\n\nAccuracy: {accuracy:.4f} \nPrecision: {precision:.4f} \nRecall: {recall:.4f} \nF1: {fscore:.4f} \nTraining Time: {train_time:.2f} sec")  

  # Create a dictionary to save all the metrics and save it for later use
  test_metrics = dict({'accuracy' : accuracy,
                       'precision': precision,
                       'recall' : recall,
                       'fscore': fscore,
                       'roc_auc': roc_auc,
                       'support': support,
                       'conf_matrix': conf_matrix,
                       'false_posrate': false_posrate,
                       'true_posrate': true_posrate,
                       'train_time': train_time,
                       'model_name': MODEL_NAME
                       })
  
  save_file(test_metrics,'test_metrics')

  # Plot AUC curve
  plt.title('Receiver Operating Characteristic')
  plt.plot(false_posrate, true_posrate, 'b', label = 'AUC = %0.2f' % roc_auc)
  plt.legend(loc = 'lower right')
  plt.plot([0, 1], [0, 1],'r--')
  plt.xlim([0, 1])
  plt.ylim([0, 1])
  plt.ylabel('True Positive Rate')
  plt.xlabel('False Positive Rate')
  plt.savefig(f"{MODEL_PATH}ROC.png")
  plt.show()

  # Show confusion matrix
  group_names = ['True Neg','False Pos','False Neg','True Pos']
  group_counts = ["{0:0.0f}".format(value) for value in
                  conf_matrix.flatten()]
  group_percentages = ["{0:.2%}".format(value) for value in
                      conf_matrix.flatten()/np.sum(conf_matrix)]
  labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
            zip(group_names,group_counts,group_percentages)]
  labels = np.asarray(labels).reshape(2,2)
  sns.heatmap(conf_matrix, annot=labels, fmt='', cmap='Blues')
  plt.savefig(f"{MODEL_PATH}Confusion Matrix.png")

  print(f"CONFUSION MATRIX\n________________\n\n{conf_matrix}")
# Out:
# TESTING METRICS
#
# Accuracy: 0.9701
# Precision: 0.9709
# Recall: 0.9701
# F1: 0.9701
# Training Time: 7052.27 sec
# CONFUSION MATRIX
# ________________
#
# [[684  36]
#  [  7 713]]
